# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [markdown]
# ---
# 1. machine learning adlah suatu metode untuk mengajarkan program membaca pola suatu data dan memprediksi data yang belum ada
# 2. data feature adalah data yang dipelajari program baik polanya atau bentuknya, data target adalah data yang akan diprediksi berdasarkan featurenya
# 3. supervised learning akan menghasilkan data target yang jelas, sementara unsupervised learning akan menghasilkan data menurut featurenya tanpa target yang jelas (label tidak jelas)
# 4. Klasifikasi adalah pengelompokan data target berdasarkan featurenya, regresi adalah prediksi data target berdasarkan data feature
# 5. hyperparameter adalah suatu parameter yang ditentukan di awal pemrograman machine learning, parameter adalah batasan yang muncul ketika data target telah muncul
# 6. - pilih algoritma yang akan digunakan
#    - pilih hyperparameter yang akan diterapkan
#    - pisahkan antara data feature dan data target (harus dalam bentuk matriks)
#    - perintahkan model untuk mempelajari data yang ada
#    - aplikasikan model untuk memprediksi data target yang diinginkan

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)

# %%
# Code here
from sklearn.svm import SVR
svr_rbf = SVR(kernel='poly', degree=2)
x2 = x.reshape(-1,1)
svr_rbf.fit(x2,y)

predik_train = svr_rbf.predict(x2)

x_new2 = x_new.reshape(-1,1)
predik = svr_rbf.predict(x_new2)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y, label='Data Asli')
ax.scatter(x, predik_train, color='k', marker='x',label='prediksi terhadap data training')
ax.plot(x_new, predik, color='r',label='Data hasil prediksi')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
ax.legend(loc='upper right',bbox_to_anchor=(1, 1.2))
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler  
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#           id  Umur                  Kelas Pekerja  Berat Akhir Pendidikan  \
# 0          0    21                     Wiraswasta       242912        SMA
# 1          1    49                     Wiraswasta       140782       10th
# 2          2    44                     Wiraswasta       120057         D3
# 3          3    24                     Wiraswasta       194630    Sarjana
# 4          4    33                     Wiraswasta       219619     Master
# ...      ...   ...                            ...          ...        ...
# 35989  35989    47  Pekerja Bebas Bukan Perusahan       148169        SMA
# 35990  35990    69       Pekerja Bebas Perusahaan       264722         D3
# 35991  35991    24  Pekerja Bebas Bukan Perusahan        31606    Sarjana
# 35992  35992    47                     Wiraswasta       197836        SMA
# 35993  35993    45                     Wiraswasta       243743    Sarjana
#
#        Jmlh Tahun Pendidikan     Status Perkawinan              Pekerjaan  \
# ...

# %%
train['Kelas Pekerja'].value_counts()
# Out:
# Wiraswasta                       24948
# Pekerja Bebas Bukan Perusahan     2866
# Pemerintah Lokal                  2280
# Pemerintah Negara                 1477
# Pekerja Bebas Perusahaan          1273
# Pemerintah Provinsi               1066
# Tanpa di Bayar                      15
# Name: Kelas Pekerja, dtype: int64

# %%
train.isin(['?']).sum()
# Out:
# id                          0
# Umur                        0
# Kelas Pekerja            2063
# Berat Akhir                 0
# Pendidikan                  0
# Jmlh Tahun Pendidikan       0
# Status Perkawinan           0
# Pekerjaan                2069
# Jenis Kelamin               0
# Keuntungan Kapital          0
# Kerugian Capital            0
# Jam per Minggu              0
# Gaji                        0
# dtype: int64

# %%
train['Kelas Pekerja'] = train['Kelas Pekerja'].replace('?',np.nan)

# %%
train['Pekerjaan'] = train['Pekerjaan'].replace('?',np.nan)

# %%
train.dropna(how='any',inplace=True)

# %%
train
# Out:
#           id  Umur                  Kelas Pekerja  Berat Akhir Pendidikan  \
# 0          0    21                     Wiraswasta       242912        SMA
# 1          1    49                     Wiraswasta       140782       10th
# 2          2    44                     Wiraswasta       120057         D3
# 3          3    24                     Wiraswasta       194630    Sarjana
# 4          4    33                     Wiraswasta       219619     Master
# ...      ...   ...                            ...          ...        ...
# 35989  35989    47  Pekerja Bebas Bukan Perusahan       148169        SMA
# 35990  35990    69       Pekerja Bebas Perusahaan       264722         D3
# 35991  35991    24  Pekerja Bebas Bukan Perusahan        31606    Sarjana
# 35992  35992    47                     Wiraswasta       197836        SMA
# 35993  35993    45                     Wiraswasta       243743    Sarjana
#
#        Jmlh Tahun Pendidikan     Status Perkawinan              Pekerjaan  \
# ...

# %%
gaji = {'<=7jt':0,'>7jt':1}
train['Gaji'] = train['Gaji'].replace(gaji)

# %%
train = train.drop(['id'],axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33925 entries, 0 to 35993
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Umur                   33925 non-null  int64
#  1   Kelas Pekerja          33925 non-null  object
#  2   Berat Akhir            33925 non-null  int64
#  3   Pendidikan             33925 non-null  object
#  4   Jmlh Tahun Pendidikan  33925 non-null  int64
#  5   Status Perkawinan      33925 non-null  object
#  6   Pekerjaan              33925 non-null  object
#  7   Jenis Kelamin          33925 non-null  object
#  8   Keuntungan Kapital     33925 non-null  float64
#  9   Kerugian Capital       33925 non-null  float64
#  10  Jam per Minggu         33925 non-null  float64
#  11  Gaji                   33925 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 3.4+ MB

# %%
train_data = train.drop(['Gaji'],axis=1)
train_hasil = train['Gaji']

pendidikan = {
    '1st-4th':1,
    '5th-6th':2,
    'SD':3,
    '7th-8th':4,
    '9th':5,
    '10th':6,
    '11th':7,
    '12th':8,
    'SMA':9,
    'Sekolah Professional':10,
    'D3':11,
    'D4':12,
    'Pendidikan Tinggi':13,
    'Sarjana':14,
    'Master':15,
    'Doktor':16    
}
train_data['Pendidikan'] = train_data['Pendidikan'].replace(pendidikan)

# %%
train_data
# Out:
#        Umur                  Kelas Pekerja  Berat Akhir  Pendidikan  \
# 0        21                     Wiraswasta       242912           9
# 1        49                     Wiraswasta       140782           6
# 2        44                     Wiraswasta       120057          11
# 3        24                     Wiraswasta       194630          14
# 4        33                     Wiraswasta       219619          15
# ...     ...                            ...          ...         ...
# 35989    47  Pekerja Bebas Bukan Perusahan       148169           9
# 35990    69       Pekerja Bebas Perusahaan       264722          11
# 35991    24  Pekerja Bebas Bukan Perusahan        31606          14
# 35992    47                     Wiraswasta       197836           9
# 35993    45                     Wiraswasta       243743          14
#
#        Jmlh Tahun Pendidikan     Status Perkawinan              Pekerjaan  \
# 0                          9  Belum Pernah Menikah         Servis Lainnya
# ...

# %%
train_data_final = pd.get_dummies(train_data)
train_data_final.columns
# Out:
# Index(['Umur', 'Berat Akhir', 'Pendidikan', 'Jmlh Tahun Pendidikan',
#        'Keuntungan Kapital', 'Kerugian Capital', 'Jam per Minggu',
#        'Kelas Pekerja_Pekerja Bebas Bukan Perusahan',
#        'Kelas Pekerja_Pekerja Bebas Perusahaan',
#        'Kelas Pekerja_Pemerintah Lokal', 'Kelas Pekerja_Pemerintah Negara',
#        'Kelas Pekerja_Pemerintah Provinsi', 'Kelas Pekerja_Tanpa di Bayar',
#        'Kelas Pekerja_Wiraswasta', 'Status Perkawinan_Belum Pernah Menikah',
#        'Status Perkawinan_Berpisah', 'Status Perkawinan_Cerai',
#        'Status Perkawinan_Janda', 'Status Perkawinan_Menikah',
#        'Status Perkawinan_Menikah LDR', 'Pekerjaan_Asisten Rumah Tangga',
#        'Pekerjaan_Ekesekutif Managerial', 'Pekerjaan_Mesin Inspeksi',
#        'Pekerjaan_Pembersih', 'Pekerjaan_Pemuka Agama', 'Pekerjaan_Penjaga',
#        'Pekerjaan_Perbaikan Kerajinan', 'Pekerjaan_Petani', 'Pekerjaan_Sales',
#        'Pekerjaan_Servis Lainnya', 'Pekerjaan_Spesialis', 'Pekerjaan_Supir',
# ...

# %%
train_hasil
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 35989    0
# 35990    1
# 35991    1
# 35992    0
# 35993    1
# Name: Gaji, Length: 33925, dtype: int64

# %%
scaler = StandardScaler()  

scaler.fit(train_data)  
train_data = scaler.transform(train_data)

test_data = scaler.transform(test_data)

# %%
ada = AdaBoostClassifier(n_estimators=100)                     
ada.fit(train_data, train_label)
ada_pred = ada.predict(test_data)
roc_auc_score(test_label,ada_pred)

# %%
test = pd.read_csv('test.csv')

# %%
test
# Out:
#          id  Umur                  Kelas Pekerja  Berat Akhir  \
# 0     35994    30               Pemerintah Lokal        99761
# 1     35995    28                     Wiraswasta       202206
# 2     35996    34            Pemerintah Provinsi       199934
# 3     35997    51                     Wiraswasta       373448
# 4     35998    20                              ?       144685
# ...     ...   ...                            ...          ...
# 9594  45588    58              Pemerintah Negara       159021
# 9595  45589    45  Pekerja Bebas Bukan Perusahan       144086
# 9596  45590    20                     Wiraswasta       238685
# 9597  45591    41               Pemerintah Lokal       249039
# 9598  45592    34  Pekerja Bebas Bukan Perusahan        24961
#
#              Pendidikan  Jmlh Tahun Pendidikan     Status Perkawinan  \
# 0                    D4                     11                 Cerai
# 1                   SMA                      9               Menikah
# ...

# %%
testid = test['id']
testid
# Out:
# 0       35994
# 1       35995
# 2       35996
# 3       35997
# 4       35998
#         ...
# 9594    45588
# 9595    45589
# 9596    45590
# 9597    45591
# 9598    45592
# Name: id, Length: 9599, dtype: int64

# %%
test.isin(['?']).sum()
# Out:
# id                         0
# Umur                       0
# Kelas Pekerja            552
# Berat Akhir                0
# Pendidikan                 0
# Jmlh Tahun Pendidikan      0
# Status Perkawinan          0
# Pekerjaan                554
# Jenis Kelamin              0
# Keuntungan Kapital         0
# Kerugian Capital           0
# Jam per Minggu             0
# dtype: int64

# %%
test['Kelas Pekerja'] = test['Kelas Pekerja'].replace('?',np.nan)
test['Pekerjaan'] = test['Pekerjaan'].replace('?',np.nan)

# %%
test = test.drop(['id'],axis=1)

# %%
test
# Out:
#       Umur                  Kelas Pekerja  Berat Akhir         Pendidikan  \
# 0       30               Pemerintah Lokal        99761                 D4
# 1       28                     Wiraswasta       202206                SMA
# 2       34            Pemerintah Provinsi       199934  Pendidikan Tinggi
# 3       51                     Wiraswasta       373448  Pendidikan Tinggi
# 4       20                            NaN       144685  Pendidikan Tinggi
# ...    ...                            ...          ...                ...
# 9594    58              Pemerintah Negara       159021                9th
# 9595    45  Pekerja Bebas Bukan Perusahan       144086               11th
# 9596    20                     Wiraswasta       238685  Pendidikan Tinggi
# 9597    41               Pemerintah Lokal       249039                SMA
# 9598    34  Pekerja Bebas Bukan Perusahan        24961                SMA
#
#       Jmlh Tahun Pendidikan     Status Perkawinan              Pekerjaan  \
# ...

# %%
test['Kelas Pekerja'].value_counts()
# Out:
# Wiraswasta                       6714
# Pekerja Bebas Bukan Perusahan     732
# Pemerintah Lokal                  624
# Pemerintah Negara                 376
# Pekerja Bebas Perusahaan          316
# Pemerintah Provinsi               279
# Tanpa di Bayar                      4
# Tidak Pernah Bekerja                2
# Name: Kelas Pekerja, dtype: int64

# %%
pendidikan = {
    '1st-4th':1,
    '5th-6th':2,
    'SD':3,
    '7th-8th':4,
    '9th':5,
    '10th':6,
    '11th':7,
    '12th':8,
    'SMA':9,
    'Sekolah Professional':10,
    'D3':11,
    'D4':12,
    'Pendidikan Tinggi':13,
    'Sarjana':14,
    'Master':15,
    'Doktor':16    
}
test['Pendidikan'] = test['Pendidikan'].replace(pendidikan)

# %%
test
# Out:
#       Umur                  Kelas Pekerja  Berat Akhir  Pendidikan  \
# 0       30               Pemerintah Lokal        99761          12
# 1       28                     Wiraswasta       202206           9
# 2       34            Pemerintah Provinsi       199934          13
# 3       51                     Wiraswasta       373448          13
# 4       20                            NaN       144685          13
# ...    ...                            ...          ...         ...
# 9594    58              Pemerintah Negara       159021           5
# 9595    45  Pekerja Bebas Bukan Perusahan       144086           7
# 9596    20                     Wiraswasta       238685          13
# 9597    41               Pemerintah Lokal       249039           9
# 9598    34  Pekerja Bebas Bukan Perusahan        24961           9
#
#       Jmlh Tahun Pendidikan     Status Perkawinan              Pekerjaan  \
# 0                        11                 Cerai           Pemuka Agama
# ...

# %%
test_final = pd.get_dummies(test)
test_final = test_final.drop(['Kelas Pekerja_Tidak Pernah Bekerja'],axis=1)
test_final
# Out:
#       Umur  Berat Akhir  Pendidikan  Jmlh Tahun Pendidikan  \
# 0       30        99761          12                     11
# 1       28       202206           9                      9
# 2       34       199934          13                     10
# 3       51       373448          13                     10
# 4       20       144685          13                     10
# ...    ...          ...         ...                    ...
# 9594    58       159021           5                      5
# 9595    45       144086           7                      7
# 9596    20       238685          13                     10
# 9597    41       249039           9                      9
# 9598    34        24961           9                      9
#
#       Keuntungan Kapital  Kerugian Capital  Jam per Minggu  \
# 0                    0.0               0.0            40.0
# 1                    0.0               0.0            50.0
# 2                    0.0               0.0            40.0
# ...

# %%
ada = AdaBoostClassifier(n_estimators=100)                     
ada.fit(train_data_final, train_hasil)
ada_pred = ada.predict(test_final)

# %%
ada_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
submit2 = pd.DataFrame([testid,ada_pred]).T

# %%
submit2.columns = ['id','Gaji']

# %%
submit2.to_csv('submit2.csv',header=True,index=False)
